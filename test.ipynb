# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamishra1602/Google-collab/blob/main/program_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program 1: Basic Variable Assignment and Type Casting
name = input("Enter student name: ")
age = int(input("Enter student age: "))
gpa = float(input("Enter student GPA: "))

print(f"\n--- Student Profile ---")
print(f"Name: {name} (Type: {type(name).__name__})")
print(f"Age: {age} (Type: {type(age).__name__})")
print(f"GPA: {gpa} (Type: {type(gpa).__name__})")

# Simple calculation using variables
years_to_grad = 22 - age
print(f"Years until age 22: {years_to_grad}")
